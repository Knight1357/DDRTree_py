# %% [markdown]
# # 构建 DDRTree C++ 代码中 PCA 降维部分的 Python PCA 降维包

# %%
# %%bash
# pwd
# cd DDRTree_py
# pwd
# rm -rf build
# mkdir -p build
# cd build
# cmake ..
# make
# Out:
# /mnt/ssd/geneplus/develop/liushen/DDRTree/test/ddrtreecpp_call_pypca
# /mnt/ssd/geneplus/develop/liushen/DDRTree/test/ddrtreecpp_call_pypca/DDRTree_py
# -- The CXX compiler identification is GNU 11.2.0
# -- Check for working CXX compiler: /opt/miniconda/bin/x86_64-conda-linux-gnu-c++
# -- Check for working CXX compiler: /opt/miniconda/bin/x86_64-conda-linux-gnu-c++ -- works
# -- Detecting CXX compiler ABI info
# -- Detecting CXX compiler ABI info - done
# -- Detecting CXX compile features
# -- Detecting CXX compile features - done
# -- Found Python3: /opt/miniconda/envs/r42/bin/python3 (found version "3.12.3") found components: Interpreter Development
# -- Performing Test HAS_FLTO
# -- Performing Test HAS_FLTO - Success
# -- Found pybind11: /opt/miniconda/include (found version "2.13.6")
# -- Python3 Interpreter: /opt/miniconda/envs/r42/bin/python3
# -- Python3 Library: /opt/miniconda/envs/r42/lib/libpython3.12.so
# ...

# %%
# %%bash
# pwd
# ./call_pca_python
# Out:
# /mnt/ssd/geneplus/develop/liushen/DDRTree/test/ddrtreecpp_call_pypca
# 2024-12-17 17:50:06.367 | WARNING  | DDRTree:pca_projection_python:22 - 开始python pca降维
# 2024-12-17 17:59:40.296 | WARNING  | DDRTree:pca_projection_python:51 - 结束python pca降维
# 2024-12-17 17:59:40.305 | INFO     | utils:wrapper:20 - 函数 pca_projection_python 开始时间： 2024-12-17 17:50:06，整体运行时间: 9.57 min
# PCA projection result:
# 0.00381645 -0.015227 -0.0262286 0.0291749 -0.0763734 0.0198371 0.00633426 0.0398923 0.0487207 0.00274529
# 0.00836376 0.00234328 0.0331443 0.00787125 0.030902 0.0202342 -0.016077 -0.00416971 -0.0170974 0.0136177
# 0.0445414 0.000886553 0.0212569 -0.0237834 -0.0215426 -0.00811518 -0.00518753 0.0129429 0.0197701 -0.00225219
# -0.0328136 -0.0160373 -0.00450095 0.02975 -0.0317048 -0.025832 -0.0701188 -0.00408082 -0.0133625 0.0156691
# -0.0413835 -0.000915214 -0.046955 -0.0214636 -0.0177563 0.0297317 -0.0358102 -0.0126022 0.0176339 -0.0111607
# ...

# %% [markdown]
# ## 测试 DDRTree.py 中的 sqdist 函数
