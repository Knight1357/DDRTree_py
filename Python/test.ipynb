# %% [markdown]
# # test ddr_tree.py

# %%
import numpy as np
import sys
import os
from loguru import logger
import ddr_tree
from utils import time_func


@time_func
def test_ddr_tree_cpp():

    # 设置随机种子
    np.random.seed(42)

    # 参数设置
    n_samples = 100000      # 样本数量（N）
    n_features = 2000    # 原始特征维度（D）
    num_clusters = 3000   # 聚类数量（K）
    dimensions = 2      # 降维后的维度（d）
    maxiter = 20        # 最大迭代次数
    sigma = 1e-3        # 高斯核参数
    lambda_ = 0.1       # 正则化参数
    gamma = 10         # 权重参数
    eps = 1e-3          # 收敛阈值
    verbose = True      # 是否输出详细信息

    # 生成可控的随机数据
    R_X = np.random.rand(n_features, n_samples)          # (D x N)
    R_Z = np.random.rand(dimensions, n_samples)          # (d x N)
    R_Y = np.random.rand(dimensions, num_clusters)       # (d x K)
    R_W = np.random.rand(n_features, dimensions)         # (D x d)

    # 检查输入数据是否有异常值
    for name, matrix in zip(['R_X', 'R_Z', 'R_Y', 'R_W'], [R_X, R_Z, R_Y, R_W]):
        assert not np.any(np.isnan(matrix)), f"{name} contains NaN values"
        assert not np.any(np.isinf(matrix)), f"{name} contains Inf values"

    # 调用函数
    logger.warning(f"开始调用 DDRTree_reduce_dim 函数")
    result = ddr_tree.DDRTree_reduce_dim_python(
        R_X, R_Z, R_Y, R_W,
        dimensions, maxiter, num_clusters,
        sigma, lambda_, gamma, eps, verbose
    )

    logger.warning(f"开始调用 DDRTree_reduce_dim 函数结束")
    # 输出结果
    print("-------------------------------------------------------------")
    print("W shape:", result['W'].shape)
    print("Z shape:", result['Z'].shape)
    print("stree shape:", result['stree'].shape)
    print("Y shape:", result['Y'].shape)
    print("X shape:", result['X'].shape)
    print("Q shape:", result['Q'].shape)
    print("R shape:", result['R'].shape)
    print("Objective values:", result['objective_vals'])


if __name__ == "__main__":
    test_ddr_tree_cpp()
# Out:
# 2024-12-23 09:31:57.983 | WARNING  | __main__:test_ddr_tree_cpp:39 - 开始调用 DDRTree_reduce_dim 函数
# 2024-12-23 09:31:57.986 | INFO     | ddr_tree:DDRTree_reduce_dim_python:130 - 初始化：细胞数量 N_cells = 100000
# 2024-12-23 09:32:02.929 | INFO     | ddr_tree:DDRTree_reduce_dim_python:143 - 构造完全图完成
# 2024-12-23 09:32:02.931 | INFO     | ddr_tree:DDRTree_reduce_dim_python:179 - 所有矩阵初始化完成
# 2024-12-23 09:32:02.932 | INFO     | ddr_tree:DDRTree_reduce_dim_python:183 - **************************************
# 2024-12-23 09:32:02.933 | INFO     | ddr_tree:DDRTree_reduce_dim_python:184 - Iteration: 0
# 2024-12-23 09:32:03.124 | INFO     | utils:wrapper:20 - 函数 sqdist_python 开始时间： 2024-12-23 09:32:02，整体运行时间: 0.0 min
# 2024-12-23 09:32:03.126 | INFO     | ddr_tree:DDRTree_reduce_dim_python:189 - distsqMU: [[1.11022302e-16 1.64822363e-02 1.80252370e-01 ... 3.92570286e-02
#   5.04508446e-01 2.00712205e-01]
#  [1.64822363e-02 0.00000000e+00 2.12205393e-01 ... 1.28947942e-02
#   4.33027604e-01 2.18125461e-01]
#  [1.80252370e-01 2.12205393e-01 0.00000000e+00 ... 1.49817301e-01
#   2.03056881e-01 3.97552302e-03]
#  ...
#  [3.92570286e-02 1.28947942e-02 1.49817301e-01 ... 0.00000000e+00
#   2.96487685e-01 1.45454311e-01]
#  [5.04508446e-01 4.33027604e-01 2.03056881e-01 ... 2.96487685e-01
#   0.00000000e+00 1.50210326e-01]
#  [2.00712205e-01 2.18125461e-01 3.97552302e-03 ... 1.45454311e-01
#   1.50210326e-01 0.00000000e+00]]
# 2024-12-23 09:32:03.127 | INFO     | ddr_tree:DDRTree_reduce_dim_python:192 - 正在更新图中的边权重...
# 2024-12-23 09:32:07.639 | INFO     | ddr_tree:DDRTree_reduce_dim_python:207 - 计算最小生成树 (MST)
# 2024-12-23 09:32:27.233 | INFO     | ddr_tree:DDRTree_reduce_dim_python:214 - Refreshing B matrix
# 2024-12-23 09:32:27.268 | INFO     | ddr_tree:DDRTree_reduce_dim_python:232 -    B : (3000 x 3000)
# 2024-12-23 09:32:27.318 | INFO     | ddr_tree:DDRTree_reduce_dim_python:242 -    拉普拉斯矩阵 L: (3000 x 3000)
# 2024-12-23 09:32:27.320 | INFO     | ddr_tree:DDRTree_reduce_dim_python:246 -    Z_out: (2 x 100000), 最大值: 0.9999930107320085
# 2024-12-23 09:32:27.321 | INFO     | ddr_tree:DDRTree_reduce_dim_python:249 -    Y_out: (2 x 3000), 最大值: 0.999877237361485
# 2024-12-23 09:32:31.804 | INFO     | utils:wrapper:20 - 函数 sqdist_python 开始时间： 2024-12-23 09:32:27，整体运行时间: 0.07 min
# 2024-12-23 09:32:31.999 | INFO     | ddr_tree:DDRTree_reduce_dim_python:257 -    distZY: (100000 x 3000), 最大值: 1.9462013673337881
# 2024-12-23 09:32:32.000 | INFO     | ddr_tree:DDRTree_reduce_dim_python:262 -    min_dist: (100000 x 3000)
# 2024-12-23 09:32:32.208 | INFO     | ddr_tree:DDRTree_reduce_dim_python:268 - distZY_minCoeff:
# 2024-12-23 09:32:32.209 | INFO     | ddr_tree:DDRTree_reduce_dim_python:269 - [2.94994641e-04 1.36160778e-04 3.55361520e-05 ... 9.13718500e-05
#  2.27555481e-05 1.22667104e-04]
# 2024-12-23 09:32:34.534 | INFO     | ddr_tree:DDRTree_reduce_dim_python:276 - min_dist:
# 2024-12-23 09:32:34.535 | INFO     | ddr_tree:DDRTree_reduce_dim_python:277 - [[2.94994641e-04 2.94994641e-04 2.94994641e-04 ... 2.94994641e-04
#   2.94994641e-04 2.94994641e-04]
#  [1.36160778e-04 1.36160778e-04 1.36160778e-04 ... 1.36160778e-04
#   1.36160778e-04 1.36160778e-04]
#  [3.55361520e-05 3.55361520e-05 3.55361520e-05 ... 3.55361520e-05
#  [4.44470222e-052 4.68232727e-025 7.78821719e-201 ... 1.53669939e-038
#   1.45570831e-260 3.09379675e-198]
#  [1.57779488e-154 8.73141888e-196 2.46553100e-031 ... 9.55282215e-169
#   5.01915354e-190 5.06160501e-043]]
# 2024-12-23 09:32:45.565 | INFO     | ddr_tree:DDRTree_reduce_dim_python:310 - R: (100000 x 3000)
# 2024-12-23 09:32:45.566 | INFO     | ddr_tree:DDRTree_reduce_dim_python:311 - [[1.58377701e-088 1.27346008e-113 3.73443562e-006 ... 3.45963070e-090
#   4.19853378e-130 6.61205772e-013]
#  [1.74553585e-078 7.52809835e-040 2.62668292e-144 ... 2.19565550e-027
#   3.95739482e-125 9.37741828e-131]
#  [2.48318177e-086 4.20651317e-132 1.61083409e-046 ... 3.75477049e-128
#   1.84760706e-260 7.70555709e-066]
#  ...
#  [1.31135467e-127 8.79955006e-130 1.68868586e-012 ... 2.02036259e-088
#   1.25950536e-043 2.85510061e-006]
#  [4.44470222e-052 4.68232727e-025 7.78821719e-201 ... 1.53669939e-038
#   1.45570831e-260 3.09379675e-198]
#  [1.57779488e-154 8.73141888e-196 2.46553100e-031 ... 9.55282215e-169
#   5.01915354e-190 5.06160501e-043]]
# 2024-12-23 09:32:45.797 | INFO     | ddr_tree:DDRTree_reduce_dim_python:318 - Gamma: (3000 x 3000)
# 2024-12-23 09:32:45.798 | INFO     | ddr_tree:DDRTree_reduce_dim_python:319 - [[34.36426438  0.          0.         ...  0.          0.
#    0.        ]
#  [ 0.         35.56383483  0.         ...  0.          0.
#    0.        ]
#  [ 0.          0.         29.74244385 ...  0.          0.
#    0.        ]
#  ...
#  [ 0.          0.          0.         ... 31.02763591  0.
#    0.        ]
#  [ 0.          0.          0.         ...  0.         26.18776314
#    0.        ]
#  [ 0.          0.          0.         ...  0.          0.
#   27.23336404]]
# 2024-12-23 09:32:52.466 | INFO     | ddr_tree:DDRTree_reduce_dim_python:326 - obj1: -206.56657394976327
# 2024-12-23 09:32:52.467 | INFO     | ddr_tree:DDRTree_reduce_dim_python:329 -    X : ( 2000 x 100000 )
# 2024-12-23 09:32:52.468 | INFO     | ddr_tree:DDRTree_reduce_dim_python:330 -    W : ( 2000 x 2 )
# 2024-12-23 09:32:52.469 | INFO     | ddr_tree:DDRTree_reduce_dim_python:331 -    Z : ( 2 x 100000 )
# 2024-12-23 09:32:54.637 | INFO     | ddr_tree:DDRTree_reduce_dim_python:342 - obj2: 36856432.247582704
# 2024-12-23 09:32:54.639 | INFO     | ddr_tree:DDRTree_reduce_dim_python:345 -    L : ( 3000 x 3000 )
# 2024-12-23 09:32:54.640 | INFO     | ddr_tree:DDRTree_reduce_dim_python:351 - Checking termination criterion
# 2024-12-23 09:32:54.641 | INFO     | ddr_tree:DDRTree_reduce_dim_python:367 - Computing tmp
# 2024-12-23 09:32:54.642 | INFO     | ddr_tree:DDRTree_reduce_dim_python:370 - ... stage 1
# 2024-12-23 09:32:54.846 | INFO     | ddr_tree:DDRTree_reduce_dim_python:378 - 稀疏矩阵 tmp: (3000, 3000), 非零元素数: 8998
# 2024-12-23 09:33:16.667 | INFO     | ddr_tree:DDRTree_reduce_dim_python:385 - tmp: tmp = tmp - (R.T @ R)
